# %%
import pandas as pd
import numpy as np

# %%
dat = pd.read_csv("/home/donghan/Downloads/C.csv", header = None)

# %%
df = dat.T
df.columns = list(range(1, len(dat.index)+1))
df
# Out:
#             1             2         3             4        5         6    \
# 0      0.095108  1.506000e-12  0.019966  1.345700e-11  0.15527  0.016918
# 1      0.094825  1.502300e-12  0.019926  1.343500e-11  0.15514  0.016895
# 2      0.094543  1.498600e-12  0.019886  1.341200e-11  0.15502  0.016871
# 3      0.094262  1.495000e-12  0.019846  1.339000e-11  0.15489  0.016848
# 4      0.093982  1.491300e-12  0.019807  1.336700e-11  0.15476  0.016824
# 5      0.093703  1.487600e-12  0.019767  1.334500e-11  0.15464  0.016801
# 6      0.093424  1.484000e-12  0.019727  1.332300e-11  0.15451  0.016777
# 7      0.093147  1.480300e-12  0.019688  1.330000e-11  0.15438  0.016754
# 8      0.092870  1.476700e-12  0.019648  1.327800e-11  0.15426  0.016730
# 9      0.092594  1.473100e-12  0.019609  1.325600e-11  0.15413  0.016707
# 10     0.092319  1.469500e-12  0.019569  1.323400e-11  0.15400  0.016684
# 11     0.092044  1.465900e-12  0.019530  1.321200e-11  0.15388  0.016660
# ...

# %%
df.corr()
